# %%
import numpy as np
import pandas as pd
import warnings 
warnings.filterwarnings(action='ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_emp_health = pd.read_csv('D:\\Abhinav\\learning\\Great Learning\\NPV\\Mini Project\\NPV - Mini - Question-1\\emp_health.csv')

df_emp_health
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 2     i10014   28    male  33.000          3   rarely    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.970          3       no    no       west
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# ...

# %%
df_emp_health.head()
# Out:
#        id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0  i10012   19  female  27.900          0    daily   yes  southwest
# 1  i10013   18    male  33.770          1  weekend    no      south
# 2  i10014   28    male  33.000          3   rarely    no      south
# 3  i10015   33    male  22.705          0    daily    no  northwest
# 4  i10016   32    male  28.880          0    party    no  northwest
#
#    expenditure
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
df_emp_health.tail()
# Out:
#           id  age     sex    bmi  dependent  alcohol smoke       zone  \
# 1333  i11345   50    male  30.97          3       no    no       west
# 1334  i11346   18  female  31.92          0    daily    no       east
# 1335  i11347   18  female  36.85          0  weekend    no  southeast
# 1336  i11348   21  female  25.80          0    party    no  southwest
# 1337  i11349   61  female  29.07          0       no   yes       west
#
#       expenditure
# 1333   10600.5483
# 1334    2205.9808
# 1335    1629.8335
# 1336    2007.9450
# 1337   29141.3603

# %%
df_emp_health.sample(5)
# Out:
#          id  age     sex     bmi  dependent alcohol smoke       zone  \
# 102  i10114   18  female  30.115          0   party    no      north
# 16   i10028   52  female  30.780          1   party    no      north
# 238  i10250   19    male  29.070          0   daily   yes  northwest
# 392  i10404   48    male  31.445          1      no    no       east
# 430  i10442   19    male  33.100          0   party    no  southwest
#
#      expenditure
# 102  21344.84670
# 16   10797.33620
# 238  17352.68030
# 392   8964.06055
# 430  23082.95533

# %%
df_emp_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1338 non-null   object
#  1   age          1338 non-null   int64
#  2   sex          1338 non-null   object
#  3   bmi          1338 non-null   float64
#  4   dependent    1338 non-null   int64
#  5   alcohol      1338 non-null   object
#  6   smoke        1338 non-null   object
#  7   zone         1338 non-null   object
#  8   expenditure  1338 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 94.2+ KB

# %%
df_emp_health.isna()
# Out:
#          id    age    sex    bmi  dependent  alcohol  smoke   zone  \
# 0     False  False  False  False      False    False  False  False
# 1     False  False  False  False      False    False  False  False
# 2     False  False  False  False      False    False  False  False
# 3     False  False  False  False      False    False  False  False
# 4     False  False  False  False      False    False  False  False
# ...     ...    ...    ...    ...        ...      ...    ...    ...
# 1333  False  False  False  False      False    False  False  False
# 1334  False  False  False  False      False    False  False  False
# 1335  False  False  False  False      False    False  False  False
# 1336  False  False  False  False      False    False  False  False
# 1337  False  False  False  False      False    False  False  False
#
#       expenditure
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 1333        False
# ...

# %%
df_emp_health.describe()
# Out:
#                age          bmi    dependent   expenditure
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # 1. How many employees above 50 age smoke, what is their average expenditure on health management?

# %%
df_emp_health[(df_emp_health.age > 50) & (df_emp_health.smoke == 'yes')]['expenditure'].mean()
# The average ecpenditure of employees above 50 age who smoke is 38820.23
# Out:
# 38820.22308234375

# %% [markdown]
# # 2. How many female employees did not consume alcohol daily. What is their proportion with respect to total female employees?

# %%
percent_female_no_daily_drinks = np.multiply(np.divide(df_emp_health[(df_emp_health.sex == 'female') & 
                                                        (df_emp_health.alcohol != 'daily')]['sex'].count() ,
                   df_emp_health[df_emp_health.sex == 'female'].count()
                   ),100)

np.round(percent_female_no_daily_drinks['sex'],2)
# The percentage of female employee did not comsume alcohol are 68.43
# Out:
# 68.43

# %% [markdown]
# # 3. Display zone wise average expenditure of employees on health

# %%
# Method 1
df_emp_health.groupby('zone')[['expenditure']].mean()
#zone wise average expenditure of employees on health is given below
# Out:
#             expenditure
# zone
# east       13774.679941
# north      14102.583403
# northeast  13694.721724
# northwest  12151.702619
# south      14715.689519
# southeast  14452.949680
# southwest  12717.083869
# west       12182.998872

# %%
#Method 2
df_emp_health.groupby('zone').expenditure.mean()
#zone wise average expenditure of employees on health is given below
# Out:
# zone
# east         13774.679941
# north        14102.583403
# northeast    13694.721724
# northwest    12151.702619
# south        14715.689519
# southeast    14452.949680
# southwest    12717.083869
# west         12182.998872
# Name: expenditure, dtype: float64

# %% [markdown]
# # 4. Employees of which zone did maximum expenditure on health

# %%
# Method 1
df_emp_health.groupby('zone').expenditure.sum().max()
# Maximum expenditure on heath by a zone is 3608966.14
# Out:
# 3608966.144489

# %%
# Method 2
df_emp_health.groupby('zone')['expenditure'].sum().max()
# Maximum expenditure on heath by a zone is 3608966.14
# Out:
# 3608966.144489

# %% [markdown]
# # 5. What is the minimum expenditure done by any employee in organization

# %%
# Method 1
df_emp_health.expenditure.min()
# Minimum expenditure done by any employee in  Organization is 1121.8739
# Out:
# 1121.8739

# %%
# Method 2
df_emp_health['expenditure'].min()
# Minimum expenditure done by any employee in  Organization is 1121.8739
# Out:
# 1121.8739

# %% [markdown]
# # 6. What is average expenditure of employees who have 2 or lesser dependents

# %%
df_emp_health[df_emp_health.dependent <= 2].expenditure.mean()
# Average expenditure of employees who have 2 or less dependents is 13040.97
# Out:
# 13040.970970948145

# %%
df_emp_health[df_emp_health['dependent'] <= 2 ]['expenditure'].mean()
# Average expenditure of employees who have 2 or less dependents is 13040.97
# Out:
# 13040.970970948145

# %% [markdown]
# # 7. How many employees are below age of 20 years. What is their average BMI

# %%
# Method 1
df_emp_health[df_emp_health.age < 20].bmi.mean()
# BMI of number of employees which are below 20 years is 29.97
# Out:
# 29.971496350364966

# %%
# Method 2
df_emp_health[df_emp_health['age'] < 20 ]['bmi'].mean()
# BMI of number of employees which are below 20 years is 29.97
# Out:
# 29.971496350364966

# %% [markdown]
# # 8. Create a dataframe "non_smoker" for all non-smoker male employees

# %%
df_male_no_smoke = df_emp_health[(df_emp_health['smoke'] == 'no') & ( df_emp_health['sex'] == 'male')]

df_male_no_smoke
# all non_smoker male employees given below
# Out:
#           id  age   sex     bmi  dependent  alcohol smoke       zone  \
# 1     i10013   18  male  33.770          1  weekend    no      south
# 2     i10014   28  male  33.000          3   rarely    no      south
# 3     i10015   33  male  22.705          0    daily    no  northwest
# 4     i10016   32  male  28.880          0    party    no  northwest
# 8     i10020   37  male  29.830          2    party    no      north
# ...      ...  ...   ...     ...        ...      ...   ...        ...
# 1324  i11336   31  male  25.935          1    daily    no       west
# 1325  i11337   61  male  33.535          0    party    no       east
# 1327  i11339   51  male  30.030          1    daily    no  southeast
# 1329  i11341   52  male  38.600          2    party    no  southwest
# 1333  i11345   50  male  30.970          3       no    no       west
#
#       expenditure
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 8      6406.41070
# ...           ...
# ...

# %%
df_male_no_smoke = df_emp_health[(df_emp_health.smoke == 'no') & (df_emp_health.sex == 'male')]
df_male_no_smoke
# all non_smoker male employees given below
# Out:
#           id  age   sex     bmi  dependent  alcohol smoke       zone  \
# 1     i10013   18  male  33.770          1  weekend    no      south
# 2     i10014   28  male  33.000          3   rarely    no      south
# 3     i10015   33  male  22.705          0    daily    no  northwest
# 4     i10016   32  male  28.880          0    party    no  northwest
# 8     i10020   37  male  29.830          2    party    no      north
# ...      ...  ...   ...     ...        ...      ...   ...        ...
# 1324  i11336   31  male  25.935          1    daily    no       west
# 1325  i11337   61  male  33.535          0    party    no       east
# 1327  i11339   51  male  30.030          1    daily    no  southeast
# 1329  i11341   52  male  38.600          2    party    no  southwest
# 1333  i11345   50  male  30.970          3       no    no       west
#
#       expenditure
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 8      6406.41070
# ...           ...
# ...

# %% [markdown]
# #  9. Create a dataframe "non_alcoholic" for all male employees who do not consume alcohol

# %%
df_male_no_achohol = df_emp_health[(df_emp_health.sex == 'male') &  (df_emp_health.alcohol == 'no')]

df_male_no_achohol
# all the male employees who donot cosume alchohol given below
# Out:
#           id  age   sex     bmi  dependent alcohol smoke       zone  \
# 18    i10030   56  male  40.300          0      no    no  southwest
# 24    i10036   37  male  28.025          2      no    no  northwest
# 28    i10040   23  male  17.385          1      no    no  northwest
# 37    i10049   26  male  20.800          0      no    no  southwest
# 38    i10050   35  male  36.670          1      no   yes      north
# ...      ...  ...   ...     ...        ...     ...   ...        ...
# 1291  i11303   19  male  34.900          0      no   yes  southwest
# 1301  i11313   62  male  30.875          3      no   yes       west
# 1310  i11322   42  male  26.315          1      no    no       west
# 1320  i11332   31  male  31.065          3      no    no       west
# 1333  i11345   50  male  30.970          3      no    no       west
#
#       expenditure
# 18    10602.38500
# 24     6203.90175
# 28     2775.19215
# 37     2302.30000
# 38    39774.27630
# ...           ...
# ...

# %% [markdown]
# # 10. Create a dataframe called "non_smoking_alcoholic" with the men employees who do not smoke and consume alcohol. The dataframe should contain columns id, smoke, alcohol

# %%
df_male_no_smoke_no_achohol = df_male_no_smoke.merge(df_male_no_achohol, on ='id'
                       ,  how='inner'
                      )[['id','smoke_x','alcohol_x']]

df_male_no_smoke_no_achohol.rename(columns={'smoke_x':'smoke','alcohol_x': 'alcohol'},inplace=True)

df_male_no_smoke_no_achohol
# all the employees which are neither smoke nor alcoholic are given
# Out:
#          id smoke alcohol
# 0    i10030    no      no
# 1    i10036    no      no
# 2    i10040    no      no
# 3    i10049    no      no
# 4    i10079    no      no
# ..      ...   ...     ...
# 104  i11273    no      no
# 105  i11282    no      no
# 106  i11322    no      no
# 107  i11332    no      no
# 108  i11345    no      no
#
# [109 rows x 3 columns]

# %% [markdown]
# # 11.What is the count for each zone with respect to number of dependent

# %%
df_count = df_emp_health.groupby(['zone','dependent'])[['id']].count()
df_count.columns = ['count']
# number of count for each zone with respect to number of dependent

# %%
df_count.reset_index(inplace=True)
df_count
# Out:
#          zone  dependent  count
# 0        east          0    124
# 1        east          1     65
# 2        east          2     42
# 3        east          3     22
# 4        east          4      6
# 5        east          5      3
# 6       north          0     26
# 7       north          1     20
# 8       north          2     10
# 9       north          3     12
# 10      north          4      1
# 11      north          5      1
# 12  northeast          0     35
# 13  northeast          1      9
# 14  northeast          2     15
# 15  northeast          3     13
# 16  northeast          4      2
# 17  northwest          0     70
# 18  northwest          1     28
# 19  northwest          2     30
# 20  northwest          3     13
# 21  northwest          4      4
# 22      south          0     38
# 23      south          1     21
# 24      south          2     12
# 25      south          3     12
# 26      south          4      1
# 27  southeast          0     81
# ...

# %% [markdown]
# # 12. Classify the employees into 3 categories.
# # Category 1 : employees below 18.5 bmi - underweight
# # Category 2 : employees with bmi in the range of 18.5 to 24.9 - fit
# # Category 3 : employee with bmi over 24.9 - overweight
# # What is the average expenditure of employees in each category.
# # Display the bar chart for the same

# %%
list1 = []
for i in df_emp_health.bmi:
    if i < 18.5:
        list1.append('underweight')
    elif i >= 18.5 and i < 24.9 :
        list1.append('fit')
    else :
        list1.append('overweight')
        
df_emp_health.insert(loc=len(df_emp_health.columns),column = 'bmi_category',value=list1)        

df_emp_health
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 2     i10014   28    male  33.000          3   rarely    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.970          3       no    no       west
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure bmi_category
# 0     16884.92400   overweight
# 1      1725.55230   overweight
# ...

# %%
df_emp_health.groupby(['bmi_category']).expenditure.mean()
# Out:
# bmi_category
# fit            10379.499732
# overweight     13936.616823
# underweight     8852.200585
# Name: expenditure, dtype: float64

# %%
plt.figure(figsize=(15,8))
plt.title('Expenditure for  employees based on all 3 category of BMI')
sns.barplot(x = df_emp_health.bmi_category, y = df_emp_health.expenditure)
plt.show()
# Below is bar chart for BMI for  employees based on all 3 category 
# Expenditure is higher for employees who is overweight and lowest for employees who is underweight

# %% [markdown]
# # 13. Draw line plot of expenditure against age and BMI

# %%
plt.figure(figsize=(15,8))
plt.title('Expenditure against age and BMI')
sns.lineplot(x = df_emp_health.age,y=df_emp_health.expenditure)
plt.show()
# expenditure is increasing with age

# %% [markdown]
# # 14. Draw a bar chart to show zone wise average expenditure

# %%
plt.figure(figsize=(15,8))
plt.title('Zone wise average expenditure')
sns.barplot(x=df_emp_health.zone,y=df_emp_health.expenditure)
plt.show()
# Expenditure of people living in South zone is highest and lowest for people living in North west and North

# %% [markdown]
# # 15. Draw a bar chart to show smoking and alcoholic habits against average expenditure

# %%
plt.figure(figsize=(15,7))
plt.subplot(121)
sns.barplot(x= df_emp_health.smoke,y=df_emp_health.expenditure)
plt.subplot(122)
sns.barplot(x=df_emp_health.alcohol,y=df_emp_health.expenditure)
plt.show()
# Most of the employees smoke and take alcohol aleast on party

# %% [markdown]
# # 16. Draw pie chart for alcohol consumption habits

# %%
plt.figure(figsize=(15,8))
plt.title('Alcohol consumption habits')
plt.pie(df_emp_health.alcohol.value_counts(), labels=['daily','weekend','party','no','rarely'],autopct="%1.2f%%")

plt.show()
#Percebnt of employees comsume alchohol daily is highest.

# %% [markdown]
# # 17. Draw scatterplot to see the relation between age and expenditure, keep smoking habit as hue

# %%
plt.figure(figsize=(15,7))
plt.title("Relation between age and expenditure")
sns.scatterplot(x=df_emp_health.age,y=df_emp_health.expenditure,hue=df_emp_health.smoke)
plt.show()
# Those employee who smoke have Higher expenditure also with age expenditure is slightly increasing

# %% [markdown]
# # 18. Draw distribution plot of expenditure

# %%
plt.figure(figsize=(15,8))
sns.displot(df_emp_health.expenditure,bins=20,kde=True)
plt.show()
# Distribution plot of expenditure
# There are more people who expenditure is around 10000

# %% [markdown]
# # 19. Display the pairplot

# %%
sns.pairplot(df_emp_health,height=10,size=4,hue = "sex",markers=['o','s'])
plt.show()

# %% [markdown]
# # 20. Display heatmap for the data

# %%
plt.figure(figsize=(15,8))
corr = df_emp_health.corr()
sns.heatmap(corr,annot=True,linewidths=2,linecolor= 'Green',square=True,robust=True)
plt.show()
# The correlation is very low for each case
